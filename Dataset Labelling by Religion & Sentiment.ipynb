# %%
# Import required packages
import numpy as np
import pandas as pd
import logging
import json
import string
import re
from pprint import pprint
import matplotlib.pyplot as plt
import joblib

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from hatesonar import Sonar

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\wajih\AppData\Roaming\Python\Python38\site-packages\mpl_toolkits\mplot3d\__init__.py:1: MatplotlibDeprecationWarning:
# The deprecated function was deprecated in Matplotlib 3.4 and will be removed two minor releases later.
#   from .axes3d import Axes3D

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: wheel in c:\anaconda3\lib\site-packages (from lightgbm) (0.37.0)
# Requirement already satisfied: numpy in c:\users\wajih\appdata\roaming\python\python38\site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scipy in c:\anaconda3\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\anaconda3\lib\site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wajih\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ysqlclient (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lack (c:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\anaconda3\lib\site-packages)

# %%
#Define stopwords
stop_words = set(stopwords.words('english'))
#You can update the stop words from here (I added "re" because it's originally "are")
stop_words.update(["governer","re","governor","watch","live","facebook","beshear","hutchinson","lousiana","youtube","mercer","middlesex","monmouth","morris","ocean","passaic", "salem","somerset", "sussex", "union","warren","update","briefing","press","conference","updates","et","news"])

# %%
def common_member(a, b):
    a_set = set(a)
    b_set = set(b)
    if (a_set & b_set):
        return True 
    else:
        return False

# %%
def clean_text(text):
    '''
    Make text lowercase, 
    remove reply, 
    remove text in square brackets, 
    remove links, 
    remove user mention,
    remove punctuation, 
    remove numbers 
    and remove words containing numbers.
    '''
    
    re_url = r'(?:http|ftp|https)://(?:[\w_-]+(?:(?:\.[\w_-]+)+))(?:[\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?' 
    text = text.lower()
    text = re.sub('^rt', ' ', text)
    text = re.sub('\[.*?\]', ' ', text)
    text = re.sub(re_url, ' ', text)
    text = re.sub('<.*?>+', ' ', text) #In this part the <u> </u> will be removed and any similar HTML balise too 
    text = re.sub('@\w+', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\n', ' ', text)
    text = re.sub('\w*\d\w*', ' ', text)
    
    return text

# %%
# Read the data
df = pd.read_excel("Raw Tweets.xlsx")

# Add the retweet column 
df['Retweet'] = ['Yes' if "RT @" in i else 'No' for i in df['Tweets'] ]

# Apply primary cleaning
df['Tweets_cleaned'] = df['Tweets'].apply(clean_text)

df['Tweets_cleaned'] = df['Tweets_cleaned'].str.split() \
    .apply(lambda x: [word for word in x if word not in stop_words]) \
    .apply(lambda x: ' '.join(x))

df.head(5)
# Out:
#        State     Role           Name  \
# 0  Minnesota  Senator  Amy Klobuchar
# 1  Minnesota  Senator  Amy Klobuchar
# 2  Minnesota  Senator  Amy Klobuchar
# 3  Minnesota  Senator  Amy Klobuchar
# 4  Minnesota  Senator  Amy Klobuchar
#
#                                               Tweets   num_date     Party  \
# 0  Seriously?  Maybe the President should focus o... 2020-03-14  Democrat
# 1  There are so many heroes on the front lines as... 2020-03-14  Democrat
# 2  RT @Yamiche : This is why @JudyWoodruff is ama... 2020-03-14  Democrat
# 3  With the House passing the #FamiliesFirstBill ... 2020-03-14  Democrat
# 4  Seniors are more at risk to the coronavirus pa... 2020-03-14  Democrat
#
#    Status Retweet                                     Tweets_cleaned
# 0       4      No  seriously maybe president focus getting testin...
# 1       4      No  many heroes front lines face pandemic nurses d...
# 2       4     Yes  amazing reminded viewers tonight think others ...
# 3       4      No  house passing familiesfirstbill last night sen...
# 4       4      No  seniors risk coronavirus pandemic cities like ...

# %%
# Vectorize this dataset using the same vocabulary used in the previous model

X = df['Tweets_cleaned']

# Load previous model vocabulary
Model_vocab = joblib.load('vocabulary.pickle') 

# Apply the vectorizer on the dataset
Tf = TfidfVectorizer(analyzer='word', ngram_range=(1,3), lowercase = True,
                          use_idf = True ,max_features = 5000000, vocabulary = Model_vocab)
X = Tf.fit_transform(X)
X
# Out:
# <61466x340198 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1112932 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Religion analysis

# %%
# Using a trained model LGBM with 99% using a public dataset

Model_ = joblib.load('classifier.pickle')
Religion_predictions = Model_.predict(X)
Religion_percentages = Model_.predict_proba(X)

# %%
no = []
yes = []
for i in Religion_percentages :
    no.append(round(i[0],2)*100)
    yes.append(round(i[1],2)*100)

# %%
def relabel(i):
    if i== 1:
        return('Yes')
    else : 
        return('No')
df['Religion'] = Religion_predictions
df['Religion'] = df['Religion'].apply(relabel)
df['Religion_No'] = no
df['Religion_Yes'] = yes
df
# Out:
#                 State     Role           Name  \
# 0           Minnesota  Senator  Amy Klobuchar
# 1           Minnesota  Senator  Amy Klobuchar
# 2           Minnesota  Senator  Amy Klobuchar
# 3           Minnesota  Senator  Amy Klobuchar
# 4           Minnesota  Senator  Amy Klobuchar
# ...               ...      ...            ...
# 61461           Texas  Senator       Ted Cruz
# 61462  South Carolina  Senator      Tim Scott
# 61463  South Carolina  Senator      Tim Scott
# 61464  South Carolina  Senator      Tim Scott
# 61465  South Carolina  Senator      Tim Scott
#
#                                                   Tweets   num_date  \
# 0      Seriously?  Maybe the President should focus o... 2020-03-14
# 1      There are so many heroes on the front lines as... 2020-03-14
# 2      RT @Yamiche : This is why @JudyWoodruff is ama... 2020-03-14
# 3      With the House passing the #FamiliesFirstBill ... 2020-03-14
# 4      Seniors are more at risk to the coronavirus pa... 2020-03-14
# ...                                                  ...        ...
# 61461  Exactly the right move. Last year @SenBillCass... 2020-05-31
# 61462  RT @postandcourier : It’s 11:00. A county-wide... 2020-05-31
# 61463  RT @FoxNewsSunday : EXCLUSIVE: Chris will be j... 2020-05-31
# 61464  For those who believe that violence is a way t... 2020-05-31
# 61465  RT @SenatorTimScott : For those who believe th... 2020-05-31
#
#             Party  Status Retweet  \
# 0        Democrat       4      No
# 1        Democrat       4      No
# 2        Democrat       4     Yes
# 3        Democrat       4      No
# 4        Democrat       4      No
# ...           ...     ...     ...
# 61461  Republican       1      No
# 61462  Republican       1     Yes
# 61463  Republican       1     Yes
# 61464  Republican       1      No
# 61465  Republican       1     Yes
#
#                                           Tweets_cleaned Religion  \
# 0      seriously maybe president focus getting testin...       No
# 1      many heroes front lines face pandemic nurses d...       No
# 2      amazing reminded viewers tonight think others ...       No
# 3      house passing familiesfirstbill last night sen...       No
# 4      seniors risk coronavirus pandemic cities like ...       No
# ...                                                  ...      ...
# 61461  exactly right move last year amp called design...       No
# 61462          it’s county wide curfew effect charleston       No
# 61463  exclusive chris joined senator tim scott discu...       No
# 61464  believe violence way react selfishness tolerat...       No
# 61465  believe violence way react selfishness tolerat...       No
#
#        Religion_No  Religion_Yes
# 0             97.0           3.0
# 1             99.0           1.0
# 2             96.0           4.0
# 3            100.0           0.0
# 4             73.0          27.0
# ...            ...           ...
# 61461         98.0           2.0
# 61462         99.0           1.0
# 61463         99.0           1.0
# 61464         99.0           1.0
# 61465         99.0           1.0
#
# [61466 rows x 12 columns]

# %% [markdown]
# ## Sentiment analysis

# %%
# Import the lexicon 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
# Download the lexicon
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\wajih\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sentiments = []
neg = []
pos = []
neu = []
analyzer = SentimentIntensityAnalyzer()

for tw in df['Tweets_cleaned']:
    vs = analyzer.polarity_scores(tw)
    del vs['compound']
    max_value = max(vs, key=vs.get)
    labels = {'neg': "negative", 'neu': "neutral", 'pos': "positive"}
    neg.append(vs['neg']*100)
    neu.append(vs['neu']*100)
    pos.append(vs['pos']*100)
    sentiments.append(labels[max_value])
    
df['Sentiments'] = sentiments
df['Negative'] = neg
df['Positive'] = pos
df['Neutral'] = neu
df

# %%
df.to_excel(r'Labeled_Tweets_By_Religion .xlsx', index = False, header = True)
